# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# plt.style.use('default')
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [10,6]
plt.rcParams["axes.edgecolor"] = "black"

# %% [markdown]
# ## Need to convert all this to numpy

# %%
# model parameters
a = 0.7
b = 0.5
c = 0.3
e = 0.2

#Time parameters
dt = 0.001
max_time = 100

# initial time and populations
t = 0
x = 1.0
y = 0.5

# init lists
t_list = [t]
x_list = [x]
y_list = [y]

while t < max_time:
    # calc new values for t, x, y
    t = t + dt
    
    # calc new values for t, x, y
    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    # store new values in lists
    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

# Plot the results    
plt.plot(t_list, x_list, 'green',linewidth = 1, ls = '-')
plt.plot(t_list, y_list, 'red',linewidth = 1, ls = '-')
plt.legend(['Prey','Predator'])
plt.title('Lotka-Volterra plot (Baseline)')
plt.xlabel('Time (arbitrary units)')
plt.ylabel('Population (arbitrary units)')
# Out:
# Text(0, 0.5, 'Population (arbitrary units)')

# %%
# model params
a = 0.7
b = 0.5
c = 0.3
e = 0.2

#time params
dt = 0.001
max_time = 100

# initial time and populations
t = 0
x = 0.5
y = 0.5

# empty lists in which to store time and populations
t_list = [t]
x_list = [x]
y_list = [y]

# simulating deaths
time_bomb_armed = True

while t < max_time:
    # calc new values for t, x, y
    t = t + dt
    
    if time_bomb_armed and t > 50:
        x = 0.1 * x
        y = 0.1 * y
        time_bomb_armed = False

    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    # store new values in lists
    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

# Plot the results    
plt.plot(t_list, x_list, 'green',linewidth = 1, ls = '-')
plt.plot(t_list, y_list, 'r',linewidth = 1, ls = '-')
plt.legend(['Prey','Predator'])
plt.title('Lotka-Volterra plot (Bombed)')
plt.xlabel('Time (arbitrary units)')
plt.ylabel('Population (arbitrary units)')
# Out:
# Text(0, 0.5, 'Population (arbitrary units)')

# %%
# model params
a = 0.7
b = 0.5
c = 0.3
e = 0.2

#time params
dt = 0.001
max_time = 300

# initial time and populations
t = 0
x = 1
y = 0.5

# empty lists in which to store time and populations
t_list = [t]
x_list = [x]
y_list = [y]

# simulating deaths
time_bomb_armed = True

while t < max_time:
    # calc new values for t, x, y
    t = t + dt
    
    if time_bomb_armed and t > 50:
        x = 0.75 * x
        y = 1 * y
        time_bomb_armed = False

    x = x + (a*x - b*x*y)*dt
    y = y + (-c*y + e*x*y)*dt

    # store new values in lists
    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

# Plot the results    
plt.plot(t_list, x_list, 'g',linewidth = 1, ls = '-')
plt.plot(t_list, y_list, 'r',linewidth = 1, ls = '-')
plt.legend(['Prey','Predator'])
plt.title('Lotka-Volterra plot (Prey hunted)')
plt.xlabel('Time (arbitrary units)')
plt.ylabel('Population (arbitrary units)')
# Out:
# Text(0, 0.5, 'Population (arbitrary units)')

# %%
# model params
a = 0.7
b = 0.5
c = 0.3
e = 0.2

#time params
dt = 0.001
max_time = 200

# initial time and populations
t = 0
x = 0.5
y = 0.5

# empty lists in which to store time and populations
t_list = [t]
x_list = [x]
y_list = [y]

# simulating deaths
time_bomb_armed = True

while t < max_time:
    # calc new values for t, x, y
    t = t + dt
    
    if time_bomb_armed and t> 50:
        x = 1 * x
        c = 1
        time_bomb_armed = False

    x = x + (a*x - b*x*y)*dt
    y = (y + (-c*y + e*x*y)*dt)

    # store new values in lists
    t_list.append(t)
    x_list.append(x)
    y_list.append(y)

# Plot the results    
plt.plot(t_list, x_list, 'g',linewidth = 1, ls = '-')
plt.plot(t_list, y_list, 'r',linewidth = 1, ls = '-')
plt.legend(['Prey','Predator'])
plt.title('Lotka-Volterra plot (Predator loss)')
plt.xlabel('Time (arbitrary units)')
plt.ylabel('Population (arbitrary units)')
# Out:
# Text(0, 0.5, 'Population (arbitrary units)')
